# %%
import torch
from torch import nn
from torch.nn import init
import numpy as np
import sys
sys.path.append("/home/kesci/input")
import d2lzh1981 as d2l

print(torch.__version__)
# Out:
# 1.3.0

# %%
# 初始化模型和各个参数
num_inputs, num_outputs, num_hiddens = 784, 10, 256

from collections import OrderedDict
# net = nn.Sequential(
#         d2l.FlattenLayer(),
#         nn.Linear(num_inputs, num_hiddens),
#         nn.ReLU(),
#         nn.Linear(num_hiddens, num_outputs), 
#         )
net = nn.Sequential(OrderedDict([
    ('flatter', d2l.FlattenLayer()),  # 数据变换层
    ('linear1', nn.Linear(num_inputs, num_hiddens)),  # 隐藏层
    ('relu', nn.ReLU()),  # 激活函数
    ('linear2', nn.Linear(num_hiddens, num_outputs))  # 输出层
    ]))

for params in net.parameters():
    init.normal_(params, mean=0, std=0.01)

# %%
# 获取数据
batch_size = 256
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size,root='/home/kesci/input/FashionMNIST2065')
# 损失函数
loss = torch.nn.CrossEntropyLoss()
# 优化器
optimizer = torch.optim.SGD(net.parameters(), lr=0.5)
# 训练
num_epochs = 5
d2l.train_ch3(net, train_iter, test_iter, loss, num_epochs, batch_size, None, None, optimizer)
# Out:
# epoch 1, loss 0.0031, train acc 0.703, test acc 0.787
# epoch 2, loss 0.0019, train acc 0.819, test acc 0.776
# epoch 3, loss 0.0017, train acc 0.842, test acc 0.718
# epoch 4, loss 0.0015, train acc 0.856, test acc 0.823
# epoch 5, loss 0.0014, train acc 0.865, test acc 0.847

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-cb4e58e61470> in <module>
# ----> 1 net.params
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     583                 return modules[name]
#     584         raise AttributeError("'{}' object has no attribute '{}'".format(
# --> 585             type(self).__name__, name))
#     586
#     587     def __setattr__(self, name, value):
#
# AttributeError: 'Sequential' object has no attribute 'params'
